# %%
# import libraries and setup the figures to display within the notebook

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# /home/akash/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
#create a plot without a semi-colon
plt.plot()
# Out:
# []

# %%
#with semi colon

plt.plot();

# %%
# plt.show() can also be used

plt.show()

# %%
# let's add some data

plt.plot([2,4,6,8])

# %%
# Create some data

x = [5,10,15,20]
y = [1,2,3,4]

# %%
# Plotting

plt.plot(x,y);

# %%
# creating a plot in version 1

fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
# second way of creating plot

fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# Easier way and more robust going forward (recommanded).This is the which can be used regularly

fig,ax = plt.subplots()
ax.plot(x,y);

# %%
# A matplotlib workflow

# 0.Import and ready matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. get data ready
x = [1,2,3,4]
y = [11,22,33,44]

# 2. setup plot

fig,ax = plt.subplots(figsize=(10,10))

# 3. plot data
ax.plot(x,y)

# 4. customize plot
ax.set(title ="Sample plot",
        xlabel="x-axis",
        ylabel="y-axis")
# 5. save and show
fig.savefig("sampleplot.png")

# %% [markdown]
# # Making the most frequently used plots using Numpy arrays
#
# The most common types of plots are
#
#
# - `line`
# - `scatter`
# - `bar`
# - `hist`
# - `subplots()`

# %%
import numpy as np

# %% [markdown]
# ### Line plot
#
# - Line plot is a default visualization type in matplotlib.

# %%
# create an numpy array

x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plotting

fig,ax =plt.subplots()
ax.plot(x,x**2)

# %% [markdown]
# ### Scatter plot

# %%
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax= plt.subplots()
ax.scatter(x,np.sin(x));

# %% [markdown]
# ### Bar graph
#
# - vertical
# - horizontal

# %%
# Creating a plot with dictionary

book_prices = {
                "5 Am Club":250,
                "Atomic Habits":300,
                "Deep Work":240
}

fig,ax = plt.subplots()
ax.bar(book_prices.keys(),book_prices.values())
ax.set(title="Book Prices",ylabel = "cost(Rs)");

# %%
# Horizontal bar graph

fig,ax = plt.subplots()
ax.barh(list(book_prices.keys()),list(book_prices.values()))
ax.set(title="Book Prices",xlabel="Cost(Rs)");

# %% [markdown]
# ### Histogram (hist)

# %%
# Making some data for normal distribution

x = np.random.randn(1000) # pulls random normal distribution

# plotting

fig,ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # random sitribution

fig,ax = plt.subplots()
ax.hist(x)
# Out:
# (array([101.,  93., 109.,  93.,  96.,  95., 110., 120.,  93.,  90.]),
#  array([0.00128447, 0.10113089, 0.20097731, 0.30082373, 0.40067015,
#         0.50051657, 0.60036299, 0.70020941, 0.80005583, 0.89990225,
#         0.99974867]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Subplots
# * Multiple plots on one figure
# https://matplotlib.org/3.1.1/gallery/recipes/create_subplots.html

# %%
# Option 1 : creating multiple subplots

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows =2,
                                         ncols=2,
                                         figsize =(10,5)
                                        )

#plotting data

ax1.plot(x,x/2);
ax2.scatter(x,np.cos(x));
ax3.bar(book_prices.keys(),book_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# option 2: creating multiple subplots

fig,ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5)
                     )
# indexing should be done,indexing here is similar to matrix

ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(100),np.random.random(100));
ax[1,0].bar(book_prices.keys(),book_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting Data directly with pandas
#
# This section uses pandas dataframe pd.plot() method on a DataFrame to plot columns directly
#
# - https://datatofish.com/plot-dataframe-pandas/
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
# - `Line`
# - `Scatter`
# - `Bar`
# - `Hist`
# - `df.plot(subplots=True,figsize=(6,6))`

# %%
import pandas as pd

# %%
# importing car sales dataset

car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Chart Visualization in pandas
#
# - https://pandas.pydata.org/docs/user_guide/visualization.html

# %%
#Start with some dummy data

ts = pd.Series(np.random.randn(1000),
               index = pd.date_range("1/1/2020",periods=1000))
ts
# Out:
# 2020-01-01   -0.324306
# 2020-01-02    0.055940
# 2020-01-03   -2.353757
# 2020-01-04    0.581766
# 2020-01-05    0.698069
#                 ...
# 2022-09-22   -1.046501
# 2022-09-23   -0.487761
# 2022-09-24   -2.563656
# 2022-09-25   -0.495936
# 2022-09-26   -1.084958
# Freq: D, Length: 1000, dtype: float64

# %%
# what does cumsum() does?

ts.cumsum()
# Out:
# 2020-01-01   -0.324306
# 2020-01-02   -0.268366
# 2020-01-03   -2.622123
# 2020-01-04   -2.040357
# 2020-01-05   -1.342288
#                 ...
# 2022-09-22   -3.424690
# 2022-09-23   -3.912451
# 2022-09-24   -6.476108
# 2022-09-25   -6.972043
# 2022-09-26   -8.057002
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot()
# Out:
# <Axes: >

# %% [markdown]
# # Working with actual data
#
# let's do a little data manipulation on our `car_sales` DataFrame

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '',regex =True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
#Removing last two zeros

car_sales["Price"]= car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add a date column

car_sales["Sale Date"] = pd.date_range("1/1/2023",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.dtypes
# Out:
# Make                     object
# Colour                   object
# Odometer (KM)             int64
# Doors                     int64
# Price                     int64
# Sale Date        datetime64[ns]
# dtype: object

# %%
# Make total sales column
#car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales.plot(x= "Sale Date",y="Total Sales");

# %% [markdown]
# # Scatter

# %%
# 

car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# # Bar

# %%
a = np.random.rand(10,4)
a
# Out:
# array([[0.08570344, 0.10050571, 0.36867588, 0.27556381],
#        [0.39756545, 0.36027818, 0.8358796 , 0.74420963],
#        [0.85350096, 0.38046311, 0.23016007, 0.08518515],
#        [0.81421911, 0.00565642, 0.69529065, 0.90216425],
#        [0.15048584, 0.01583103, 0.91170712, 0.19002713],
#        [0.52513694, 0.27291889, 0.37380529, 0.40651713],
#        [0.68117312, 0.3034881 , 0.22268542, 0.96584725],
#        [0.62377116, 0.31017945, 0.77079857, 0.62792187],
#        [0.8079333 , 0.71651634, 0.01832613, 0.54039212],
#        [0.39385629, 0.39698997, 0.67750941, 0.49131258]])

# %%
df = pd.DataFrame(a,columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.085703  0.100506  0.368676  0.275564
# 1  0.397565  0.360278  0.835880  0.744210
# 2  0.853501  0.380463  0.230160  0.085185
# 3  0.814219  0.005656  0.695291  0.902164
# 4  0.150486  0.015831  0.911707  0.190027
# 5  0.525137  0.272919  0.373805  0.406517
# 6  0.681173  0.303488  0.222685  0.965847
# 7  0.623771  0.310179  0.770799  0.627922
# 8  0.807933  0.716516  0.018326  0.540392
# 9  0.393856  0.396990  0.677509  0.491313

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
# with car_sales dataset

car_sales.plot(x="Make",y="Odometer (KM)" ,kind="bar");

# %%
car_sales.plot(x="Make",y="Price",kind="bar");

# %% [markdown]
# ## Histograms

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
#default number of bins is 10

car_sales["Price"].plot(kind="hist",bins=20);

# %%
car_sales["Price"].plot(kind="hist");

# %% [markdown]
# # Heart Disease Data set

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50);

# %% [markdown]
# ## Subplots

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True);

# %%
# The above fig is not in proper way
# fix the fig size 

heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ### Plotting using Object Oriented Method
#
# - https://matplotlib.org/matplotblog/posts/pyplot-vs-object-oriented-interface/
# - Obiect Oriented method can be used for more complicated methods

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# performing data analysis on patients over 50+ age

over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method

over_50.plot(kind="scatter",
             x='age',
             y='chol',
             c='target',
            figsize=(10,6));

# %%
## OO Method mixed with pyplot

fig, ax = plt.subplots(figsize=(10,6))

over_50.plot(kind="scatter",
            x='age',
            y='chol',
            c='target',
             ax=ax);
ax.set_xlim([45,100]);

# %%
## OO Method from scratch

# create a plot
fig,ax = plt.subplots(figsize=(10,6))

# plot the data

scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])


# customize the plot

ax.set(title="Heart Disease and Cholestrol Levels",
      xlabel="Age",
      ylabel="Cholestrol");

ax.legend(*scatter.legend_elements(),title="Target")

# add the mean line

ax.axhline(over_50["chol"].mean(),
          linestyle="--");
